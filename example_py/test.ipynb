# %%
"""実行例"""

# %%
import sys
sys.path.append('../example_py/')
import example_0
import example_1
import example_2
import example_3

# %%
# ex0
example_0.do_example_0()
# Out:
# [1.0, 1.1, 1.2, 1.4, 1.6, 1.8, 2.0, 2.2, 2.4, 2.7, 3.0, 3.3, 3.6, 4.0, 4.4, 4.8, 5.2, 5.6, 6.0, 6.5, 7.0, 7.5, 8.0, 8.6, 9.2, 9.8, 10.4, 11.0, 11.6, 12.3, 13.0, 13.7, 14.4, 15.2, 16.0, 16.8, 17.6, 18.4, 19.2, 20.1, 21.0, 21.9, 22.8, 23.8, 24.8, 25.8, 26.8, 27.8, 28.8, 29.9, 31.0, 32.1, 33.2, 34.4, 35.6, 36.8, 38.0, 39.2, 40.4, 41.7, 43.0, 44.3, 45.6, 47.0, 48.4, 49.8, 51.2, 52.6, 54.0, 55.5, 57.0, 58.5, 60.0, 61.6, 63.2, 64.8, 66.4, 68.0, 69.6, 71.3, 73.0, 74.7, 76.4, 78.2, 80.0, 81.8, 83.6, 85.4, 87.2, 89.1, 91.0, 92.9, 94.8, 96.8, 98.8, 100.8, 102.8, 104.8, 106.8, 108.9]

# %%
# ex1
example_1.func_example_1(threshold = 40,)
# Out:
# Files with x of 40 or more is
# data_2.csv
# data_4.csv

# %%
# ex2
example_2.do_example_2()

# %%
# ex3
example_3.do_example_3()
